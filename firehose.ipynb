# %%
import requests
import json
import pandas as pd
import configparser
import csv
import datetime
import numpy as np
import time

config = configparser.ConfigParser()
config.read('ex_config.ini')
duration_API = config['push_data']['duration_API']
url = config['api']['url']



df1 = pd.read_csv('testing_data.txt', header=None)


a = df1.shape[0]
b = df1.shape[1]


def instructions_data_structure(timeslice_str):
    arr = timeslice_str.split(';')
    if len(arr) != 14:
        return timeslice_str
    else:
        instructions = {}
        instructions['STATUS_EQUIPMENT']=int(arr[0])
        instructions['STATUS_FAN']=int(arr[1])
        instructions['VOLTAGE_INPUT']=float(arr[2])
        instructions['CURRENT_INPUT']=float(arr[3])
        instructions['PRESSURE_OUTPUT']=float(arr[4])
        instructions['TEMPERATURE_OUTPUT']=int(arr[5])
        instructions['KW_FAN']=float(arr[6])
        instructions['KW_EQUIPMENT']=float(arr[7])
        instructions['FREQ_FAN']=float(arr[8])
        instructions['KW_SUMMARY']=float(arr[9])
        instructions['PRESSURE_EQUIPMENT']=float(arr[10])
        instructions['TEMPERATURE_EQUIPMENT']=int(arr[11])
        instructions['TEMPERATURE_ENVIRONMENT']=float(arr[12])
        return instructions
c = 0
d = []

for i in range(a):
    for ii in range(0, b - 2):
        if type(df1[df1.columns[ii]][i]) == float or type(df1[df1.columns[ii]][i]) == np.float64:
            pass
        else:
            fields = {}
            fields = instructions_data_structure(df1[df1.columns[ii]][i])
            d = []
            d.append(fields)
            print(d)
            e = {}
            e['data']=d
            r = requests.post(url, json=e)
            time.sleep(int(duration_API))
            c = 0
            print (e)

print ("end")
# Out:
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.9, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.9, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.1, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.3, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.1, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.3, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.1, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.3, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.1, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.3, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.1, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.1, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.1, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.3, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.1, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.3, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.9, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.9, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.1, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.3, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.1, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.3, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.7, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.9, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.7, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.9, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.7, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.9, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.7, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.9, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.7, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.9, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.7, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.9, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.7, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.9, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.7, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.9, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.7, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.9, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.7, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.9, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.7, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.9, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.7, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.9, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.7, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.9, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.7, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.9, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 39.0, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.2, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 39.0, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.2, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 39.0, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.2, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 39.0, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.2, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 129.0, 'PRESSURE_OUTPUT': 7.3, 'TEMPERATURE_OUTPUT': 99, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.8, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 38.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 0, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 87.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 100, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 26.0, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 24.9, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 0, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 87.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 100, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 26.0, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 24.9, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 0, 'VOLTAGE_INPUT': 214.8, 'CURRENT_INPUT': 75.0, 'PRESSURE_OUTPUT': 6.8, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 23.0, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 22.2, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 0, 'VOLTAGE_INPUT': 214.8, 'CURRENT_INPUT': 75.0, 'PRESSURE_OUTPUT': 6.8, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 23.0, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 22.2, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 0, 'VOLTAGE_INPUT': 214.8, 'CURRENT_INPUT': 70.0, 'PRESSURE_OUTPUT': 6.6, 'TEMPERATURE_OUTPUT': 95, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 21.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 20.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 0, 'VOLTAGE_INPUT': 214.8, 'CURRENT_INPUT': 70.0, 'PRESSURE_OUTPUT': 6.6, 'TEMPERATURE_OUTPUT': 95, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 21.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 20.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 0, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 66.0, 'PRESSURE_OUTPUT': 6.5, 'TEMPERATURE_OUTPUT': 94, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 20.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 19.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 0, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 66.0, 'PRESSURE_OUTPUT': 6.5, 'TEMPERATURE_OUTPUT': 94, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 20.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 19.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 112.0, 'PRESSURE_OUTPUT': 6.5, 'TEMPERATURE_OUTPUT': 94, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 34.6, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 34.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 112.0, 'PRESSURE_OUTPUT': 6.5, 'TEMPERATURE_OUTPUT': 94, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 34.6, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 34.0, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 125.0, 'PRESSURE_OUTPUT': 6.8, 'TEMPERATURE_OUTPUT': 95, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.6, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 36.8, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 125.0, 'PRESSURE_OUTPUT': 6.8, 'TEMPERATURE_OUTPUT': 95, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.6, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 36.8, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 125.0, 'PRESSURE_OUTPUT': 6.9, 'TEMPERATURE_OUTPUT': 95, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.6, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 36.8, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 125.0, 'PRESSURE_OUTPUT': 6.9, 'TEMPERATURE_OUTPUT': 95, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.6, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 36.8, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 6.9, 'TEMPERATURE_OUTPUT': 96, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.9, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 6.9, 'TEMPERATURE_OUTPUT': 96, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.9, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 6.9, 'TEMPERATURE_OUTPUT': 96, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.9, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 6.9, 'TEMPERATURE_OUTPUT': 96, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.9, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 6.9, 'TEMPERATURE_OUTPUT': 96, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.6, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 36.8, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 6.9, 'TEMPERATURE_OUTPUT': 96, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.6, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 36.8, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 6.9, 'TEMPERATURE_OUTPUT': 96, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.9, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 6.9, 'TEMPERATURE_OUTPUT': 96, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.9, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 6.9, 'TEMPERATURE_OUTPUT': 96, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.9, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 6.9, 'TEMPERATURE_OUTPUT': 96, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.9, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 96, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.9, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 96, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.9, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 96, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.9, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 96, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.9, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 96, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 96, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# ...
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 100, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 100, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.9, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.9, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.1, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.3, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.1, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.3, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.1, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.3, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.1, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.3, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.1, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.1, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.1, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.3, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.1, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.3, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.9, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 37.9, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.1, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.1, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.3, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 126.0, 'PRESSURE_OUTPUT': 7.0, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.1, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.3, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.7, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.9, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.7, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.9, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.1, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 97, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.2, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.4, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 213.2, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.5, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.7, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# {'data': [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 127.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.4, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.6, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]}
# [{'STATUS_EQUIPMENT': 1, 'STATUS_FAN': 1, 'VOLTAGE_INPUT': 214.0, 'CURRENT_INPUT': 128.0, 'PRESSURE_OUTPUT': 7.2, 'TEMPERATURE_OUTPUT': 98, 'KW_FAN': 0.8, 'KW_EQUIPMENT': 38.7, 'FREQ_FAN': 0.0, 'KW_SUMMARY': 37.9, 'PRESSURE_EQUIPMENT': 0.0, 'TEMPERATURE_EQUIPMENT': 0, 'TEMPERATURE_ENVIRONMENT': 0.0}]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-8f65b8061f82> in <module>()
#      58             e['data']=d
#      59             r = requests.post(url, json=e)
# ---> 60             time.sleep(int(duration_API))
#      61             c = 0
#      62             print (e)
#
# KeyboardInterrupt:

# %%
# !pip install requests pandas influxdb numpy configparser
